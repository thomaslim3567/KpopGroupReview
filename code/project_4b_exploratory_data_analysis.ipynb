# %% [markdown]
# # Project 4B: Kpop Group Lifespan Analysis

# %% [markdown]
# ### Overall Contents:
# - Background
# - Data Cleaning
# - [Exploratory Data Analysis](#3.-Exploratory-Data-Analysis) **(In this notebook)**
#
# - Evaluation
# - Conclusion and Recommendation

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# ### 3.1 Libraries Import

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline 
# Maximum display of columns
pd.options.display.max_colwidth = 400
pd.options.display.max_rows = 400

# %% [markdown]
# ### 3.2 Data Import

# %%
# Import data from csv
musicgroup_df = pd.read_csv('../data/musicgroup_cleaned.csv')
trend_df = pd.read_csv('../data/kpoptrend_cleaned.csv',index_col = 0)

# %%
musicgroup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   group_name                   705 non-null    object
#  1   company                      705 non-null    object
#  2   group_type                   705 non-null    object
#  3   debute_year                  705 non-null    int64
#  4   disband_year                 705 non-null    int64
#  5   current_status               705 non-null    object
#  6   social_accounts              705 non-null    int64
#  7   inactive_members             705 non-null    int64
#  8   current_members              705 non-null    int64
#  9   original_members_remainding  705 non-null    int64
#  10  initial_members              705 non-null    int64
#  11  member_changes               705 non-null    int64
#  12  subunits                     705 non-null    int64
#  13  albums                       705 non-null    int64
#  14  mini_albums                  705 non-null    int64
#  15  other_albums                 705 non-null    int64
#  16  singles                      705 non-null    int64
#  17  digital_singles              705 non-null    int64
#  18  other_singles                705 non-null    int64
#  19  foreign_albums               705 non-null    int64
#  20  foreign_mini_albums          705 non-null    int64
#  21  foreign_other_album          705 non-null    int64
#  22  foreign_singles              705 non-null    int64
#  23  foreign_digital_singles      705 non-null    int64
#  24  foreign_other_singles        705 non-null    int64
#  25  others                       705 non-null    int64
#  26  last_production_year         705 non-null    int64
# dtypes: int64(23), object(4)
# memory usage: 148.8+ KB

# %%
trend_df.head()
# Out:
#          trend
# 2004-01      6
# 2004-02      5
# 2004-03      3
# 2004-04      7
# 2004-05      4

# %%
trend_df.index = pd.to_datetime(trend_df.index)

# %%
trend_df
# Out:
#             trend
# 2004-01-01      6
# 2004-02-01      5
# 2004-03-01      3
# 2004-04-01      7
# 2004-05-01      4
# 2004-06-01      7
# 2004-07-01      5
# 2004-08-01      6
# 2004-09-01      6
# 2004-10-01      5
# 2004-11-01      6
# 2004-12-01      4
# 2005-01-01      4
# 2005-02-01      4
# 2005-03-01      4
# 2005-04-01      3
# 2005-05-01      4
# 2005-06-01      6
# 2005-07-01      5
# 2005-08-01      5
# 2005-09-01      4
# 2005-10-01      4
# 2005-11-01      5
# 2005-12-01      5
# 2006-01-01      5
# 2006-02-01      3
# 2006-03-01      4
# 2006-04-01      5
# 2006-05-01      3
# 2006-06-01      4
# 2006-07-01      3
# 2006-08-01      3
# 2006-09-01      3
# 2006-10-01      4
# 2006-11-01      3
# 2006-12-01      4
# 2007-01-01      3
# 2007-02-01      4
# 2007-03-01      4
# 2007-04-01      4
# 2007-05-01      3
# 2007-06-01      3
# 2007-07-01      3
# 2007-08-01      4
# 2007-09-01      2
# 2007-10-01      2
# 2007-11-01      3
# 2007-12-01      3
# 2008-01-01      2
# 2008-02-01      3
# 2008-03-01      3
# 2008-04-01      3
# 2020-04-01     76
# 2020-05-01     83
# 2020-06-01    100
# 2020-07-01     85
# 2020-08-01     87
# 2020-09-01     89
# 2020-10-01     81
# 2020-11-01     80
# 2020-12-01     88
# 2021-01-01     86
# 2021-02-01     79
# 2021-03-01     83
# 2021-04-01     81
# 2021-05-01     81

# %%
trend_df = trend_df.resample('1Y').mean()

# %%
trend_df
# Out:
#                 trend
# 2004-12-31   5.333333
# 2005-12-31   4.416667
# 2006-12-31   3.666667
# 2007-12-31   3.166667
# 2008-12-31   3.083333
# 2009-12-31   6.083333
# 2010-12-31  14.833333
# 2011-12-31  30.500000
# 2012-12-31  46.583333
# 2013-12-31  44.833333
# 2014-12-31  45.916667
# 2015-12-31  50.416667
# 2016-12-31  56.750000
# 2017-12-31  61.083333
# 2018-12-31  63.083333
# 2019-12-31  64.833333
# 2020-12-31  79.500000
# 2021-12-31  82.000000

# %%
trend_df.index = pd.to_datetime(trend_df.index).year

# %%
trend_df
# Out:
#           trend
# 2004   5.333333
# 2005   4.416667
# 2006   3.666667
# 2007   3.166667
# 2008   3.083333
# 2009   6.083333
# 2010  14.833333
# 2011  30.500000
# 2012  46.583333
# 2013  44.833333
# 2014  45.916667
# 2015  50.416667
# 2016  56.750000
# 2017  61.083333
# 2018  63.083333
# 2019  64.833333
# 2020  79.500000
# 2021  82.000000

# %% [markdown]
# ### 3.3 Feature Engineering

# %% [markdown]
# ### 3.3.1 Total Releases
#
# We create a feature for the number of releases throughout the group's carrer.

# %%
activities = list(musicgroup_df)[13:26]
musicgroup_df['total_releases'] = musicgroup_df[activities].sum(axis=1)

# %% [markdown]
# ### 3.3.1 Dummify group_types
#
# As group_type consist of only 'male' and 'female' we replace them to 1(male) and 0(female)

# %%
musicgroup_df.group_type = musicgroup_df.group_type.map(lambda x : 1 if x == 'Male' else 0)

# %% [markdown]
# ### 3.3.2 Data spliting
#
# We split the data into one that consist of groups that are still active and the other that has officially been disbanded. Modeling will be done on the disbanded set while the active set will be used for actual testing of our model.

# %%
# used for modeling
disband_df = musicgroup_df[musicgroup_df.current_status == 'Disband']
# used for testing
active_df = musicgroup_df[musicgroup_df.current_status == 'Active']

# %%
disband_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374 entries, 1 to 704
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   group_name                   374 non-null    object
#  1   company                      374 non-null    object
#  2   group_type                   374 non-null    int64
#  3   debute_year                  374 non-null    int64
#  4   disband_year                 374 non-null    int64
#  5   current_status               374 non-null    object
#  6   social_accounts              374 non-null    int64
#  7   inactive_members             374 non-null    int64
#  8   current_members              374 non-null    int64
#  9   original_members_remainding  374 non-null    int64
#  10  initial_members              374 non-null    int64
#  11  member_changes               374 non-null    int64
#  12  subunits                     374 non-null    int64
#  13  albums                       374 non-null    int64
#  14  mini_albums                  374 non-null    int64
#  15  other_albums                 374 non-null    int64
#  16  singles                      374 non-null    int64
#  17  digital_singles              374 non-null    int64
#  18  other_singles                374 non-null    int64
#  19  foreign_albums               374 non-null    int64
#  20  foreign_mini_albums          374 non-null    int64
#  21  foreign_other_album          374 non-null    int64
#  22  foreign_singles              374 non-null    int64
#  23  foreign_digital_singles      374 non-null    int64
#  24  foreign_other_singles        374 non-null    int64
#  25  others                       374 non-null    int64
#  26  last_production_year         374 non-null    int64
#  27  total_releases               374 non-null    int64
# dtypes: int64(25), object(3)
# memory usage: 84.7+ KB

# %%
active_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331 entries, 0 to 702
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   group_name                   331 non-null    object
#  1   company                      331 non-null    object
#  2   group_type                   331 non-null    int64
#  3   debute_year                  331 non-null    int64
#  4   disband_year                 331 non-null    int64
#  5   current_status               331 non-null    object
#  6   social_accounts              331 non-null    int64
#  7   inactive_members             331 non-null    int64
#  8   current_members              331 non-null    int64
#  9   original_members_remainding  331 non-null    int64
#  10  initial_members              331 non-null    int64
#  11  member_changes               331 non-null    int64
#  12  subunits                     331 non-null    int64
#  13  albums                       331 non-null    int64
#  14  mini_albums                  331 non-null    int64
#  15  other_albums                 331 non-null    int64
#  16  singles                      331 non-null    int64
#  17  digital_singles              331 non-null    int64
#  18  other_singles                331 non-null    int64
#  19  foreign_albums               331 non-null    int64
#  20  foreign_mini_albums          331 non-null    int64
#  21  foreign_other_album          331 non-null    int64
#  22  foreign_singles              331 non-null    int64
#  23  foreign_digital_singles      331 non-null    int64
#  24  foreign_other_singles        331 non-null    int64
#  25  others                       331 non-null    int64
#  26  last_production_year         331 non-null    int64
#  27  total_releases               331 non-null    int64
# dtypes: int64(25), object(3)
# memory usage: 75.0+ KB

# %% [markdown]
# ### 3.3.3 Lifespan column
#
# We caluculate the lifespan of each music group by taking the year they are disband minus the year that they debuted and add one to it.

# %%
disband_df['lifespan'] = disband_df.disband_year-disband_df.debute_year + 1
# Out:
# <ipython-input-16-34964bad2848>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disband_df['lifespan'] = disband_df.disband_year-disband_df.debute_year + 1

# %% [markdown]
# We also can now drop the column 'current_status' and 'disband_year' as we have no need for it anymore

# %%
disband_df.drop('current_status',axis = 1 ,inplace = True)
active_df.drop('current_status',axis = 1 ,inplace = True)
# Out:
# C:\Users\Thomas\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ### 3.3.3 Subset of data split into male and female groups
#
# We futher split the data into male and female group to see how they compare with each other.

# %%
female_disband_df = disband_df[disband_df.group_type == 0]
male_disband_df = disband_df[disband_df.group_type == 1]

# %%
female_df = musicgroup_df[musicgroup_df.group_type == 0]
male_df = musicgroup_df[musicgroup_df.group_type == 1]

# %% [markdown]
# ### 3.3.3 Correlation Heatmap
# we take a look at the correlation of each columns in a form of a heatmap

# %%
corr = disband_df.drop(['group_name','company'], axis = 1)
plt.figure(figsize=(20,20))
sns.heatmap(corr.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We notice that foreign_other_singles blank as that is because its all 0s in the columns.
# There are also some highly correlated datas with disband_year. This is not an issue as we will be dropping that column later as it is not required.
#
# One other highly correlated pair "debute_year" and "last_production_year" this indicates to us that most groups tend to not make it pass the first year of their debute year. We can see this in more details in the later part of the EDA
#
# lastly we notice that "foreign_other_singles" is missing its data. this is because the entire feature is filled with 0s thus it did not provide any useful information. This feature will be removed

# %%
disband_df.drop('foreign_other_singles',axis = 1 ,inplace = True)
active_df.drop('foreign_other_singles',axis = 1 ,inplace = True)
# Out:
# C:\Users\Thomas\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ### 3.4 Analysis - Average lifespan of a group

# %%
plt.figure(figsize=(10,10))
sns.histplot(disband_df.lifespan, bins =50)
plt.xlim(0,25)
plt.ylim(0,120)
# Out:
# (0.0, 120.0)

# %%
disband_df.lifespan.mean()
# Out:
# 3.671122994652406

# %%
plt.figure(figsize=(10,10))
sns.histplot(male_disband_df.lifespan, bins =50)
plt.xlim(0,25)
plt.ylim(0,30)
# Out:
# (0.0, 30.0)

# %%
 male_disband_df.lifespan.mean()
# Out:
# 3.9210526315789473

# %%
plt.figure(figsize=(10,10))
sns.histplot(female_disband_df.lifespan, bins =50)
plt.xlim(0,25)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
female_disband_df.lifespan.mean()
# Out:
# 3.5615384615384613

# %%
plt.figure(figsize=(10,10))
sns.histplot(disband_df.disband_year, bins =50)
plt.xlim(1990,2022)
# Out:
# (1990.0, 2022.0)

# %%
plt.figure(figsize=(10,10))
sns.histplot(male_disband_df.disband_year, bins =50)
plt.xlim(1990,2022)
# Out:
# (1990.0, 2022.0)

# %%
plt.figure(figsize=(10,10))
sns.histplot(female_disband_df.disband_year, bins =50)
plt.xlim(1990,2022)
# Out:
# (1990.0, 2022.0)

# %%
plt.figure(figsize=(10,10))
sns.histplot(disband_df.debute_year, bins =50)
plt.xlim(1990,2022)
# Out:
# (1990.0, 2022.0)

# %%
yearly_active =pd.DataFrame()
for year in range(musicgroup_df.debute_year.min(),musicgroup_df.disband_year.max()):
    yearly_active[year] = [len(musicgroup_df[(musicgroup_df.debute_year >= year) & (musicgroup_df.debute_year <= year)])]
male_yearly_active =pd.DataFrame()
for year in range(musicgroup_df.debute_year.min(),musicgroup_df.disband_year.max()):
    male_yearly_active[year] = [len(male_df[(male_df.debute_year >= year) & (male_df.debute_year <= year)])]
female_yearly_active =pd.DataFrame()
for year in range(musicgroup_df.debute_year.min(),musicgroup_df.disband_year.max()):
    female_yearly_active[year] = [len(female_df[(female_df.debute_year >= year) & (female_df.debute_year <= year)])]

# %%
plt.figure(figsize=(10,10))
plt.bar(yearly_active.columns, yearly_active.iloc[0])
plt.bar(yearly_active.columns, female_yearly_active.iloc[0])
plt.bar(yearly_active.columns, male_yearly_active.iloc[0])
plt.plot(trend_df)
plt.xlim(1990,2022)
# Out:
# (1990.0, 2022.0)

# %% [markdown]
# From the chart we see that the number of active group in a year increase quite steeply from the year 2008 onwards. This coincide with the data collected from google where it shows the trend of the term 'kpop'.
#
# We also notice that in the earlier years the female groups tend to outnumber the male groups. However from the last two years we see that the numbers are starting to even out. This is not due to have more active male groups but the disbanding of multple female groups.
#
# Lastly the amount of active groups each year seems to be leveling off since 2013 dispite the increasing trend. We speculate that this could be the current upper limit of the market industry which it is able to support.

# %% [markdown]
# ## dropping irrelavant data for train-test split

# %%
#disband_df.drop('disband_year',axis = 1 ,inplace = True)
#active_df.drop('disband_year',axis = 1 ,inplace = True)

# %% [markdown]
# ### 3.7 Train/Test-Split

# %% [markdown]
# ### 3.8. Summary

# %% [markdown]
# ## Exporting Data

# %%
# Placed the # to refrain from executing
disband_df.to_csv("../data/disband_train.csv", index = False)
active_df.to_csv("../data/active_test.csv", index = False)
